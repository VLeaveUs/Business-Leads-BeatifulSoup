# %%
import requests
import xlwt
from bs4 import BeautifulSoup

# %%
# Requesting the HTML script of the website
baseURL = 'https://www.science-park.co.uk'
URL = 'https://www.science-park.co.uk/about-the-park/business-directory' # add here target website
page = requests.get(URL)

# Creating Soup Object
soup = BeautifulSoup(page.content, 'html.parser')

# print(soup.prettify()) # -- print interpretably if needed

# %%
# adjusting soup to include container with business info
targclass = soup.find_all('div', class_='l-container c-business__list')

# idenitfying bussinesses' web links
targlinks = []  # links stored here
for class1 in targclass:
    targattr = class1.find_all('a')
for attr in targattr:
    targlinks.append(attr['href'])
targlinks
# Out:
# ['/about-the-park/business-directory/81g-blue',
#  '/about-the-park/business-directory/aareon-uk',
#  '/about-the-park/business-directory/absolar-solutions',
#  '/about-the-park/business-directory/accelercomm-ltd',
#  '/about-the-park/business-directory/atelier-studios',
#  '/about-the-park/business-directory/audioscenic',
#  '/about-the-park/business-directory/augmented-solutions-ltd',
#  '/about-the-park/business-directory/avonglen',
#  '/about-the-park/business-directory/building',
#  '/about-the-park/business-directory/c2visions',
#  '/about-the-park/business-directory/cascoda',
#  '/about-the-park/business-directory/chilworth-partnership',
#  '/about-the-park/business-directory/chilworth-technology-ltd',
#  '/businesses/critical-software',
#  '/about-the-park/business-directory/crondall-energy',
#  '/about-the-park/business-directory/dekra-process-safety',
#  '/about-the-park/business-directory/democracy-technology',
#  '/about-the-park/business-directory/device-access-uk-ltd',
#  '/about-the-park/business-directory/dynamon',
#  '/about-the-park/business-directory/emmerse-studios-ltd',
#  '/about-the-park/business-directory/englyst-carbohydrates-ltd',
#  '/about-the-park/business-directory/enims-ltd',
#  '/about-the-park/business-directory/fibercore-ltd',
#  '/about-the-park/business-directory/filament',
#  '/about-the-park/business-directory/forensic-genomics-innovation-hub',
#  '/about-the-park/business-directory/fresh-relevance',
#  '/about-the-park/business-directory/grant-thornton-uk-llp',
#  '/about-the-park/business-directory/gresham-tech',
#  '/about-the-park/business-directory/hilight-semiconductor',
#  '/about-the-park/business-directory/horizon-power-energy-ltd',
#  '/about-the-park/business-directory/icure-programme',
#  '/businesses/imeta-technologies-ltd',
#  '/about-the-park/business-directory/imosphere-ltd-uk',
#  '/about-the-park/business-directory/inflowmatix',
#  '/about-the-park/business-directory/itdev',
#  '/about-the-park/business-directory/jacobs',
#  '/about-the-park/business-directory/jasper-therapeutics',
#  '/businesses/korusys-ltd',
#  '/about-the-park/business-directory/liberatii-ltd',
#  '/about-the-park/business-directory/made-and-worn',
#  '/about-the-park/business-directory/mambo-tox-ltd',
#  '/about-the-park/business-directory/mantella',
#  '/about-the-park/business-directory/materialise-uk-southampton',
#  '/about-the-park/business-directory/maverick-aviation-ltd',
#  '/about-the-park/business-directory/meda-technologies-ltd',
#  '/about-the-park/business-directory/merck-chemicals',
#  '/businesses/microgem',
#  '/about-the-park/business-directory/multiple-access-communications-ltd',
#  '/about-the-park/business-directory/netscc',
#  '/about-the-park/business-directory/nihr-arc-wessex',
#  '/about-the-park/business-directory/nine23-ltd',
#  '/about-the-park/business-directory/nquiringminds-ltd',
#  '/about-the-park/business-directory/oat-services-ltd',
#  '/about-the-park/business-directory/one-pension-consultancy-llp',
#  '/about-the-park/business-directory/optomel-ltd',
#  '/about-the-park/business-directory/orthoview',
#  '/about-the-park/business-directory/otsuka-health-solutions',
#  '/about-the-park/business-directory/oxya',
#  '/about-the-park/business-directory/peter-hall',
#  '/about-the-park/business-directory/photonics',
#  '/about-the-park/business-directory/pivotal',
#  '/about-the-park/business-directory/pplus-skin-care',
#  '/about-the-park/business-directory/promega-uk-ltd',
#  '/about-the-park/business-directory/pt-solutions-ltd',
#  '/about-the-park/business-directory/quantum-solutions',
#  '/about-the-park/business-directory/renovos',
#  '/about-the-park/business-directory/semantic',
#  '/about-the-park/business-directory/senseye',
#  '/about-the-park/business-directory/shtac',
#  '/about-the-park/business-directory/skipjaq',
#  '/about-the-park/business-directory/sooba-medical-limited',
#  '/about-the-park/business-directory/southwestsensor-ltd-southampton-science-park',
#  '/about-the-park/business-directory/spectrum-it-recruitment',
#  '/about-the-park/business-directory/swedish-biomimetics-3000',
#  '/about-the-park/business-directory/taicaan',
#  '/about-the-park/business-directory/talon-operating-ltd',
#  '/about-the-park/business-directory/tekever-ltd',
#  '/about-the-park/business-directory/the-invisible-assistant',
#  '/about-the-park/business-directory/the-it-innovation-centre',
#  '/about-the-park/business-directory/tonic-analytics',
#  '/about-the-park/business-directory/trackback',
#  '/about-the-park/business-directory/troudigital',
#  '/about-the-park/business-directory/u4global',
#  '/about-the-park/business-directory/uniq-technology',
#  '/businesses/utonomy-ltd',
#  '/about-the-park/business-directory/vantia',
#  '/about-the-park/business-directory/venture-recruitment-partners',
#  '/about-the-park/business-directory/vivamos',
#  '/about-the-park/business-directory/wessex-academic-health-science-network',
#  '/about-the-park/business-directory/wessex-institute',
#  '/about-the-park/business-directory/wood-plc',
#  '/about-the-park/business-directory/xim',
#  '/about-the-park/business-directory/zenergi-ltd',
#  '/about-the-park/business-directory/zygem']

# %%
# creating workbook to export data to
scrapDB = xlwt.Workbook()

# create sheet and format
sheet1 = scrapDB.add_sheet('Science Park', cell_overwrite_ok=True)
style = xlwt.easyxf('font: bold 1') 

# column titles
sheet1.write(0, 0, 'NAME', style)
sheet1.write(0, 1, 'WEBSITE', style) 
sheet1.write(0, 2, 'LOCATION', style) 
sheet1.write(0, 3, 'EMAIL', style)
sheet1.write(0, 4, 'TEL', style)

# %%
# Exporting target bussiness data to workbook - name, website, location, tel.number, email
for num, link in enumerate(targlinks, 1):
    name = link.split('/')
    name = name[-1] # name 
    sheet1.write(num, 0, name)

    compURL = baseURL + link
    nextpage = requests.get(compURL) # switching to bussiness' websites for the data
    soup2 = BeautifulSoup(nextpage.content, 'html.parser')
    buzzclass = soup2.find_all('div', class_='o-info')
    for class2 in buzzclass:
        buzzdets = class2.find_all('a')
        #print(buzzdets)
    for i, detail in enumerate(buzzdets, 1):
        sheet1.write(num, i, detail['href'])

scrapDB.save('sciencepark_soup.xls') # saving workbook on local dir
